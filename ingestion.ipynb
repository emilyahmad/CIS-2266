# %% [markdown]
# Emily Ahmad
# 2/6/2026

# %%
sum = float(0)
count = int(0)
file = str(input("Enter file name\n"))
try: # validate
    fhand = open(file)
    for line in fhand:
        if line.startswith('X-DSPAM-Confidence'):
            temp = float(line[-6:])
            count += 1
            # print("Current line: " + str(count) + " new confidence: " + str(temp))
            sum += temp
            # print("Current sum: " + str(sum))
    print("Count: " + str(count) + "\nMean: " + str(sum/count))
except:
    print("Unable to open file")
# Out:
# Enter file name
#  mbox-short.txt
# Count: 27
# Mean: 0.7507185185185187
