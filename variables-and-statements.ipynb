# %% [markdown]
# Emily Ahmad
# 1/25/2026

# %%
hours = input("Hours worked:\n")
rate = input("Rate per hour:\n")
companyPay = float(hours) * float(rate)
print("Gross company pay: " + str(companyPay))
# Out:
# Hours worked:
#  35
# Rate per hour:
#  2.75
# Gross company pay: 96.25
